# %%
import librosa
import matplotlib.pyplot as plt
import librosa.display
import numpy as np
import os

# %%
y_raw, sr_raw = librosa.load('源.wav',44100)
librosa.display.waveplot(y_raw, sr=sr_raw)

# %%
hop_length = 512
oenv = librosa.onset.onset_strength(y=y, sr=sr, hop_length=hop_length)
tempogram = librosa.feature.fourier_tempogram(onset_envelope=oenv, sr=sr,
                                         hop_length=hop_length)

# %%
plt.plot(oenv, label='Onset strength')

# %%
y_out, sr_out = librosa.load('改.wav',44100)
librosa.display.waveplot(y_out, sr=sr_out)

# %%
hop_length = 512
oenv2 = librosa.onset.onset_strength(y=y, sr=sr, hop_length=hop_length)
tempogram2 = librosa.feature.fourier_tempogram(onset_envelope=oenv, sr=sr,
                                         hop_length=hop_length)

# %%
plt.plot(oenv2, label='Onset strength')
